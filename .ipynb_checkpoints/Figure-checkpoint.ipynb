# %%
import matplotlib.pyplot as plt
import matplotlib
import tensorflow as tf
import numpy as np
import pdb
import scipy.io as sio
import numpy as np
import pandas as pd
from pylab import rcParams
import pickle
import copy
import random
import math
import time

F=open("E:/revisiondata/three_samples_heatmap",'rb')

heatmaps=pickle.load(F)

F.close()

# %%
img1=np.array(np.array(copy.deepcopy(heatmaps[0])).sum(axis=2))
img2=np.array(np.array(copy.deepcopy(heatmaps[1])).sum(axis=2))
# big1=float(max(img1.reshape(900,1)))
# big2=float(max(img2.reshape(900,1)))
# for i in range(len(img1)):
#     for j in range(len(img1)):
#         img1[i][j]/=big1
#         img2[i][j]/=big2
#print(img1-img2)
fig=plt.figure(figsize=(7.5,6))
tmp=plt.imshow(np.reshape(img1-img2, (30,30)),cmap="Blues")
#tmp=plt.imshow(np.reshape(img2, (30,30)),cmap="Oranges")
plt.axis('off')
tt=fig.colorbar(tmp)
tt.ax.tick_params(labelsize=20)
plt.show()
#plt.show()
plt.savefig("E:/revisiondata/SpringFestival.png",dpi=300)

# %%
fig=plt.figure(figsize=(7.5,6))
#tmp=plt.imshow(np.reshape(img1, (30,30)),cmap="Blues")
tmp=plt.imshow(np.reshape(img2, (30,30)),cmap="Oranges")
plt.axis('off')
tt=fig.colorbar(tmp)
tt.ax.tick_params(labelsize=20)
plt.show()
